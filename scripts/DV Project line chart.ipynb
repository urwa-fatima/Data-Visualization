# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('owid-covid-data.csv')
print(df)
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 244333      ZWE    Africa     Zimbabwe  2022-12-17     259356.0        0.0
# 244334      ZWE    Africa     Zimbabwe  2022-12-18     259356.0        0.0
# 244335      ZWE    Africa     Zimbabwe  2022-12-19     259356.0        0.0
# 244336      ZWE    Africa     Zimbabwe  2022-12-20     259981.0      625.0
# 244337      ZWE    Africa     Zimbabwe  2022-12-21     259981.0        NaN
#
# ...

# %%
df = df[df['continent'] == 'Asia'] 
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 242317      YEM      Asia        Yemen  2022-12-17      11945.0        0.0
# 242318      YEM      Asia        Yemen  2022-12-18      11945.0        0.0
# 242319      YEM      Asia        Yemen  2022-12-19      11945.0        0.0
# 242320      YEM      Asia        Yemen  2022-12-20      11945.0        0.0
# 242321      YEM      Asia        Yemen  2022-12-21      11945.0        0.0
#
# ...

# %%
dff = df.groupby(by=["month","year","location"])['new_cases'].sum()
print(dff)
# Out:
# month  year  location
# 1      2020  Cambodia                   1.0
#              China                   9236.0
#              Hong Kong                 12.0
#              India                      1.0
#              Japan                     13.0
#                                       ...
# 12     2022  Turkey                     0.0
#              United Arab Emirates    2016.0
#              Uzbekistan              2525.0
#              Vietnam                 7659.0
#              Yemen                      0.0
# Name: new_cases, Length: 1749, dtype: float64

# %%
grouped_region_data = dff.reset_index()
# grouped_region_data['ratio'] = grouped_region_data['new_deaths']/grouped_region_data['new_vaccinations']
grouped_region_data.replace([np.inf, -np.inf], 0, inplace=True)
grouped_region_data.replace(np.nan, 0, inplace=True)
grouped_region_data.replace(to_replace="NULL",value=0)


grouped_region_data = grouped_region_data[grouped_region_data['year'] == 2020] 
print(grouped_region_data[grouped_region_data['year'] == 2020])
# Out:
#       month  year              location  new_cases
# 0         1  2020              Cambodia        1.0
# 1         1  2020                 China     9236.0
# 2         1  2020             Hong Kong       12.0
# 3         1  2020                 India        1.0
# 4         1  2020                 Japan       13.0
# ...     ...   ...                   ...        ...
# 1643     12  2020                Turkey   746580.0
# 1644     12  2020  United Arab Emirates    38962.0
# 1645     12  2020            Uzbekistan     3966.0
# 1646     12  2020               Vietnam      118.0
# 1647     12  2020                 Yemen       22.0
#
# [530 rows x 4 columns]

# %%
# grouped_region_data['ratio'] = grouped_region_data['ratio'].apply(lambda x: '%.5f' % x)

# %%
grouped_region_data.to_csv(r'C:\Users\Kozy-Korpesh\Desktop\unige 2 course\dv\dv-final\data\line_data.csv',index=False,header=True)
