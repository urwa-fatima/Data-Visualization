# %%
# import numpy as np
import pandas as pd
import geopandas as gp

# %%
# read files
data = gp.read_file("../data/owid-covid-data.csv")

# %%
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 248856 entries, 0 to 248855
# Data columns (total 68 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    248856 non-null  object
#  1   continent                                   248856 non-null  object
#  2   location                                    248856 non-null  object
#  3   date                                        248856 non-null  object
#  4   total_cases                                 248856 non-null  object
#  5   new_cases                                   248856 non-null  object
#  6   new_cases_smoothed                          248856 non-null  object
#  7   total_deaths                                248856 non-null  object
#  8   new_deaths                                  248856 non-null  object
# ...

# %%
continent_df = data.groupby("continent")

# %%
continent_df
# Out:
#                                                         iso_code  \
# continent
#                OWID_AFROWID_AFROWID_AFROWID_AFROWID_AFROWID_A...
# Africa         DZADZADZADZADZADZADZADZADZADZADZADZADZADZADZAD...
# Asia           AFGAFGAFGAFGAFGAFGAFGAFGAFGAFGAFGAFGAFGAFGAFGA...
# Europe         ALBALBALBALBALBALBALBALBALBALBALBALBALBALBALBA...
# North America  AIAAIAAIAAIAAIAAIAAIAAIAAIAAIAAIAAIAAIAAIAAIAA...
# Oceania        AUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSAUSA...
# South America  ARGARGARGARGARGARGARGARGARGARGARGARGARGARGARGA...
#
#                                                         location  \
# continent
#                AfricaAfricaAfricaAfricaAfricaAfricaAfricaAfri...
# Africa         AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Asia           AfghanistanAfghanistanAfghanistanAfghanistanAf...
# Europe         AlbaniaAlbaniaAlbaniaAlbaniaAlbaniaAlbaniaAlba...
# North America  AnguillaAnguillaAnguillaAnguillaAnguillaAnguil...
# ...
