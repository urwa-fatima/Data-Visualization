# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('owid-covid-data.csv')
print(data)
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 244333      ZWE    Africa     Zimbabwe  2022-12-17     259356.0        0.0
# 244334      ZWE    Africa     Zimbabwe  2022-12-18     259356.0        0.0
# 244335      ZWE    Africa     Zimbabwe  2022-12-19     259356.0        0.0
# 244336      ZWE    Africa     Zimbabwe  2022-12-20     259981.0      625.0
# 244337      ZWE    Africa     Zimbabwe  2022-12-21     259981.0        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 244333               0.000        5622.0         0.0                0.000
# 244334               0.000        5622.0         0.0                0.000
# 244335               0.000        5622.0         0.0                0.000
# 244336              89.286        5637.0        15.0                2.143
# 244337                 NaN        5637.0         NaN                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0       ...           NaN                  37.746                         0.5
# 1       ...           NaN                  37.746                         0.5
# 2       ...           NaN                  37.746                         0.5
# 3       ...           NaN                  37.746                         0.5
# 4       ...           NaN                  37.746                         0.5
# ...     ...           ...                     ...                         ...
# 244333  ...          30.7                  36.791                         1.7
# 244334  ...          30.7                  36.791                         1.7
# 244335  ...          30.7                  36.791                         1.7
# 244336  ...          30.7                  36.791                         1.7
# 244337  ...          30.7                  36.791                         1.7
#
#         life_expectancy  human_development_index  population  \
# 0                 64.83                    0.511  41128772.0
# 1                 64.83                    0.511  41128772.0
# 2                 64.83                    0.511  41128772.0
# 3                 64.83                    0.511  41128772.0
# 4                 64.83                    0.511  41128772.0
# ...                 ...                      ...         ...
# 244333            61.49                    0.571  16320539.0
# 244334            61.49                    0.571  16320539.0
# 244335            61.49                    0.571  16320539.0
# 244336            61.49                    0.571  16320539.0
# 244337            61.49                    0.571  16320539.0
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 244333                                   NaN                          NaN
# 244334                                   NaN                          NaN
# 244335                                   NaN                          NaN
# 244336                                   NaN                          NaN
# 244337                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 244333               NaN                                      NaN
# 244334               NaN                                      NaN
# 244335               NaN                                      NaN
# 244336               NaN                                      NaN
# 244337               NaN                                      NaN
#
# [244338 rows x 67 columns]

# %%
data_2 = pd.read_csv("world-happiness-report-2021.csv")
data_2['Regional_indicator'] = data_2['Regional indicator']
data_2 = data_2.set_index('Country name')
data_2
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# ...                                      ...           ...           ...
# Lesotho                                0.120         3.748         3.276
# Botswana                               0.074         3.611         3.322
# Rwanda                                 0.068         3.548         3.282
# Zimbabwe                               0.058         3.259         3.030
# Afghanistan                            0.038         2.596         2.449
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Finland                      10.775           0.954                   72.000
# Denmark                      10.933           0.954                   72.700
# Switzerland                  11.117           0.942                   74.400
# Iceland                      10.878           0.983                   73.000
# Netherlands                  10.932           0.942                   72.400
# ...                             ...             ...                      ...
# Lesotho                       7.926           0.787                   48.700
# Botswana                      9.782           0.784                   59.269
# Rwanda                        7.676           0.552                   61.400
# Zimbabwe                      7.943           0.750                   56.201
# Afghanistan                   7.695           0.463                   52.493
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                              0.949      -0.098
# Denmark                              0.946       0.030
# Switzerland                          0.919       0.025
# Iceland                              0.955       0.160
# Netherlands                          0.913       0.175
# ...                                    ...         ...
# Lesotho                              0.715      -0.131
# Botswana                             0.824      -0.246
# Rwanda                               0.897       0.061
# Zimbabwe                             0.677      -0.047
# Afghanistan                          0.382      -0.102
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Finland                           0.186                      2.43
# Denmark                           0.179                      2.43
# Switzerland                       0.292                      2.43
# Iceland                           0.673                      2.43
# Netherlands                       0.338                      2.43
# ...                                 ...                       ...
# Lesotho                           0.915                      2.43
# Botswana                          0.801                      2.43
# Rwanda                            0.167                      2.43
# Zimbabwe                          0.821                      2.43
# Afghanistan                       0.924                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Finland                                  1.446                         1.106
# Denmark                                  1.502                         1.108
# Switzerland                              1.566                         1.079
# Iceland                                  1.482                         1.172
# Netherlands                              1.501                         1.079
# ...                                        ...                           ...
# Lesotho                                  0.451                         0.731
# Botswana                                 1.099                         0.724
# Rwanda                                   0.364                         0.202
# Zimbabwe                                 0.457                         0.649
# Afghanistan                              0.370                         0.000
#
#               Explained by: Healthy life expectancy  \
# Country name
# Finland                                       0.741
# Denmark                                       0.763
# Switzerland                                   0.816
# Iceland                                       0.772
# Netherlands                                   0.753
# ...                                             ...
# Lesotho                                       0.007
# Botswana                                      0.340
# Rwanda                                        0.407
# Zimbabwe                                      0.243
# Afghanistan                                   0.126
#
#               Explained by: Freedom to make life choices  \
# Country name
# Finland                                            0.691
# Denmark                                            0.686
# Switzerland                                        0.653
# Iceland                                            0.698
# Netherlands                                        0.647
# ...                                                  ...
# Lesotho                                            0.405
# Botswana                                           0.539
# Rwanda                                             0.627
# Zimbabwe                                           0.359
# Afghanistan                                        0.000
#
#               Explained by: Generosity  \
# Country name
# Finland                          0.124
# Denmark                          0.208
# Switzerland                      0.204
# Iceland                          0.293
# Netherlands                      0.302
# ...                                ...
# Lesotho                          0.103
# Botswana                         0.027
# Rwanda                           0.227
# Zimbabwe                         0.157
# Afghanistan                      0.122
#
#               Explained by: Perceptions of corruption  Dystopia + residual  \
# Country name
# Finland                                         0.481                3.253
# Denmark                                         0.485                2.868
# Switzerland                                     0.413                2.839
# Iceland                                         0.170                2.967
# Netherlands                                     0.384                2.798
# ...                                               ...                  ...
# Lesotho                                         0.015                1.800
# Botswana                                        0.088                0.648
# Rwanda                                          0.493                1.095
# Zimbabwe                                        0.075                1.205
# Afghanistan                                     0.010                1.895
#
#               Regional_indicator
# Country name
# Finland           Western Europe
# Denmark           Western Europe
# Switzerland       Western Europe
# Iceland           Western Europe
# Netherlands       Western Europe
# ...                          ...
# Lesotho       Sub-Saharan Africa
# Botswana      Sub-Saharan Africa
# Rwanda        Sub-Saharan Africa
# Zimbabwe      Sub-Saharan Africa
# Afghanistan           South Asia
#
# [149 rows x 20 columns]

# %%
df = data.join(data_2, on="location")
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 244333      ZWE    Africa     Zimbabwe  2022-12-17     259356.0        0.0
# 244334      ZWE    Africa     Zimbabwe  2022-12-18     259356.0        0.0
# 244335      ZWE    Africa     Zimbabwe  2022-12-19     259356.0        0.0
# 244336      ZWE    Africa     Zimbabwe  2022-12-20     259981.0      625.0
# 244337      ZWE    Africa     Zimbabwe  2022-12-21     259981.0        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 244333               0.000        5622.0         0.0                0.000
# 244334               0.000        5622.0         0.0                0.000
# 244335               0.000        5622.0         0.0                0.000
# 244336              89.286        5637.0        15.0                2.143
# 244337                 NaN        5637.0         NaN                  NaN
#
#         ...  Perceptions of corruption  Ladder score in Dystopia  \
# 0       ...                      0.924                      2.43
# 1       ...                      0.924                      2.43
# 2       ...                      0.924                      2.43
# 3       ...                      0.924                      2.43
# 4       ...                      0.924                      2.43
# ...     ...                        ...                       ...
# 244333  ...                      0.821                      2.43
# 244334  ...                      0.821                      2.43
# 244335  ...                      0.821                      2.43
# 244336  ...                      0.821                      2.43
# 244337  ...                      0.821                      2.43
#
#         Explained by: Log GDP per capita  Explained by: Social support  \
# 0                                  0.370                         0.000
# 1                                  0.370                         0.000
# 2                                  0.370                         0.000
# 3                                  0.370                         0.000
# 4                                  0.370                         0.000
# ...                                  ...                           ...
# 244333                             0.457                         0.649
# 244334                             0.457                         0.649
# 244335                             0.457                         0.649
# 244336                             0.457                         0.649
# 244337                             0.457                         0.649
#
#         Explained by: Healthy life expectancy  \
# 0                                       0.126
# 1                                       0.126
# 2                                       0.126
# 3                                       0.126
# 4                                       0.126
# ...                                       ...
# 244333                                  0.243
# 244334                                  0.243
# 244335                                  0.243
# 244336                                  0.243
# 244337                                  0.243
#
#         Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                            0.000                     0.122
# 1                                            0.000                     0.122
# 2                                            0.000                     0.122
# 3                                            0.000                     0.122
# 4                                            0.000                     0.122
# ...                                            ...                       ...
# 244333                                       0.359                     0.157
# 244334                                       0.359                     0.157
# 244335                                       0.359                     0.157
# 244336                                       0.359                     0.157
# 244337                                       0.359                     0.157
#
#         Explained by: Perceptions of corruption  Dystopia + residual  \
# 0                                         0.010                1.895
# 1                                         0.010                1.895
# 2                                         0.010                1.895
# 3                                         0.010                1.895
# 4                                         0.010                1.895
# ...                                         ...                  ...
# 244333                                    0.075                1.205
# 244334                                    0.075                1.205
# 244335                                    0.075                1.205
# 244336                                    0.075                1.205
# 244337                                    0.075                1.205
#
#         Regional_indicator
# 0               South Asia
# 1               South Asia
# 2               South Asia
# 3               South Asia
# 4               South Asia
# ...                    ...
# 244333  Sub-Saharan Africa
# 244334  Sub-Saharan Africa
# 244335  Sub-Saharan Africa
# 244336  Sub-Saharan Africa
# 244337  Sub-Saharan Africa
#
# [244338 rows x 87 columns]

# %%
df = df[df['continent'] == 'Asia'] 
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month
df.head(6000)
# Out:
# <ipython-input-39-b668f7d6bbfc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = pd.DatetimeIndex(df['date']).year
# <ipython-input-39-b668f7d6bbfc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = pd.DatetimeIndex(df['date']).month
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1          AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 25526      BTN      Asia       Bhutan  2022-06-17      59644.0        0.0
# 25527      BTN      Asia       Bhutan  2022-06-18      59644.0        0.0
# 25528      BTN      Asia       Bhutan  2022-06-19      59644.0        0.0
# 25529      BTN      Asia       Bhutan  2022-06-20      59674.0       30.0
# 25530      BTN      Asia       Bhutan  2022-06-21      59674.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 25526               1.143          21.0         0.0                  0.0  ...
# 25527               1.143          21.0         0.0                  0.0  ...
# 25528               1.143          21.0         0.0                  0.0  ...
# 25529               4.286          21.0         0.0                  0.0  ...
# 25530               4.286          21.0         0.0                  0.0  ...
#
#        Explained by: Log GDP per capita  Explained by: Social support  \
# 0                                  0.37                           0.0
# 1                                  0.37                           0.0
# 2                                  0.37                           0.0
# 3                                  0.37                           0.0
# 4                                  0.37                           0.0
# ...                                 ...                           ...
# 25526                               NaN                           NaN
# 25527                               NaN                           NaN
# 25528                               NaN                           NaN
# 25529                               NaN                           NaN
# 25530                               NaN                           NaN
#
#        Explained by: Healthy life expectancy  \
# 0                                      0.126
# 1                                      0.126
# 2                                      0.126
# 3                                      0.126
# 4                                      0.126
# ...                                      ...
# 25526                                    NaN
# 25527                                    NaN
# 25528                                    NaN
# 25529                                    NaN
# 25530                                    NaN
#
#        Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                             0.0                     0.122
# 1                                             0.0                     0.122
# 2                                             0.0                     0.122
# 3                                             0.0                     0.122
# 4                                             0.0                     0.122
# ...                                           ...                       ...
# 25526                                         NaN                       NaN
# 25527                                         NaN                       NaN
# 25528                                         NaN                       NaN
# 25529                                         NaN                       NaN
# 25530                                         NaN                       NaN
#
#        Explained by: Perceptions of corruption  Dystopia + residual  \
# 0                                         0.01                1.895
# 1                                         0.01                1.895
# 2                                         0.01                1.895
# 3                                         0.01                1.895
# 4                                         0.01                1.895
# ...                                        ...                  ...
# 25526                                      NaN                  NaN
# 25527                                      NaN                  NaN
# 25528                                      NaN                  NaN
# 25529                                      NaN                  NaN
# 25530                                      NaN                  NaN
#
#        Regional_indicator  year  month
# 0              South Asia  2020      2
# 1              South Asia  2020      2
# 2              South Asia  2020      2
# 3              South Asia  2020      2
# 4              South Asia  2020      2
# ...                   ...   ...    ...
# 25526                 NaN  2022      6
# 25527                 NaN  2022      6
# 25528                 NaN  2022      6
# 25529                 NaN  2022      6
# 25530                 NaN  2022      6
#
# [6000 rows x 89 columns]

# %%
df.loc[df['location']=='Bhutan','Regional_indicator'] = 'South Asia'
df.loc[df['location']=='Brunei','Regional_indicator'] = 'Southeast Asia'
df.loc[df['location']=='Timor','Regional_indicator'] = 'Southeast Asia'
df.loc[df['location']=='Hong Kong','Regional_indicator'] = 'East Asia'
df.loc[df['location']=='Macao','Regional_indicator'] = 'East Asia'
df.loc[df['location']=='Taiwan','Regional_indicator'] = 'East Asia'
df.loc[df['location']=='North Korea','Regional_indicator'] = 'East Asia'
df.loc[df['location']=='Syria','Regional_indicator'] = 'Middle East and North Africa'
df.loc[df['location']=='Northern Cyprus','Regional_indicator_'] = 'Middle East and North Africa'
df.loc[df['location']=='Oman','Regional_indicator'] = 'Middle East and North Africa'
df.loc[df['location']=='Palestine','Regional_indicator'] = 'Middle East and North Africa'
# Out:
# C:\Users\Kozy-Korpesh\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Kozy-Korpesh\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)

# %%
df['Regional_indicator_id'] = df.groupby(['Regional_indicator']).ngroup()
df.head(6000)
# Out:
# <ipython-input-41-574c04d4b959>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Regional_indicator_id'] = df.groupby(['Regional_indicator']).ngroup()
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1          AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 25526      BTN      Asia       Bhutan  2022-06-17      59644.0        0.0
# 25527      BTN      Asia       Bhutan  2022-06-18      59644.0        0.0
# 25528      BTN      Asia       Bhutan  2022-06-19      59644.0        0.0
# 25529      BTN      Asia       Bhutan  2022-06-20      59674.0       30.0
# 25530      BTN      Asia       Bhutan  2022-06-21      59674.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 25526               1.143          21.0         0.0                  0.0  ...
# 25527               1.143          21.0         0.0                  0.0  ...
# 25528               1.143          21.0         0.0                  0.0  ...
# 25529               4.286          21.0         0.0                  0.0  ...
# 25530               4.286          21.0         0.0                  0.0  ...
#
#        Explained by: Healthy life expectancy  \
# 0                                      0.126
# 1                                      0.126
# 2                                      0.126
# 3                                      0.126
# 4                                      0.126
# ...                                      ...
# 25526                                    NaN
# 25527                                    NaN
# 25528                                    NaN
# 25529                                    NaN
# 25530                                    NaN
#
#        Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                             0.0                     0.122
# 1                                             0.0                     0.122
# 2                                             0.0                     0.122
# 3                                             0.0                     0.122
# 4                                             0.0                     0.122
# ...                                           ...                       ...
# 25526                                         NaN                       NaN
# 25527                                         NaN                       NaN
# 25528                                         NaN                       NaN
# 25529                                         NaN                       NaN
# 25530                                         NaN                       NaN
#
#        Explained by: Perceptions of corruption  Dystopia + residual  \
# 0                                         0.01                1.895
# 1                                         0.01                1.895
# 2                                         0.01                1.895
# 3                                         0.01                1.895
# 4                                         0.01                1.895
# ...                                        ...                  ...
# 25526                                      NaN                  NaN
# 25527                                      NaN                  NaN
# 25528                                      NaN                  NaN
# 25529                                      NaN                  NaN
# 25530                                      NaN                  NaN
#
#        Regional_indicator  year  month  Regional_indicator_  \
# 0              South Asia  2020      2                  NaN
# 1              South Asia  2020      2                  NaN
# 2              South Asia  2020      2                  NaN
# 3              South Asia  2020      2                  NaN
# 4              South Asia  2020      2                  NaN
# ...                   ...   ...    ...                  ...
# 25526          South Asia  2022      6                  NaN
# 25527          South Asia  2022      6                  NaN
# 25528          South Asia  2022      6                  NaN
# 25529          South Asia  2022      6                  NaN
# 25530          South Asia  2022      6                  NaN
#
#        Regional_indicator_id
# 0                          3
# 1                          3
# 2                          3
# 3                          3
# 4                          3
# ...                      ...
# 25526                      3
# 25527                      3
# 25528                      3
# 25529                      3
# 25530                      3
#
# [6000 rows x 91 columns]

# %%
# df['region'] = 
df.loc[df['Regional_indicator_id']==3, 'region'] = 'SA'
df.loc[df['Regional_indicator_id']==2, 'region'] = 'ME'
df.loc[df['Regional_indicator_id']==1, 'region'] = 'EA'
df.loc[df['Regional_indicator_id']==4, 'region'] = 'SEA'
df.loc[df['Regional_indicator_id']==0, 'region'] = 'CWIS'

df.head(6000)
# Out:
# C:\Users\Kozy-Korpesh\anaconda3\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Kozy-Korpesh\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Kozy-Korpesh\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Kozy-Korpesh\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Kozy-Korpesh\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Kozy-Korpesh\anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1          AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 25526      BTN      Asia       Bhutan  2022-06-17      59644.0        0.0
# 25527      BTN      Asia       Bhutan  2022-06-18      59644.0        0.0
# 25528      BTN      Asia       Bhutan  2022-06-19      59644.0        0.0
# 25529      BTN      Asia       Bhutan  2022-06-20      59674.0       30.0
# 25530      BTN      Asia       Bhutan  2022-06-21      59674.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 25526               1.143          21.0         0.0                  0.0  ...
# 25527               1.143          21.0         0.0                  0.0  ...
# 25528               1.143          21.0         0.0                  0.0  ...
# 25529               4.286          21.0         0.0                  0.0  ...
# 25530               4.286          21.0         0.0                  0.0  ...
#
#        Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                             0.0                     0.122
# 1                                             0.0                     0.122
# 2                                             0.0                     0.122
# 3                                             0.0                     0.122
# 4                                             0.0                     0.122
# ...                                           ...                       ...
# 25526                                         NaN                       NaN
# 25527                                         NaN                       NaN
# 25528                                         NaN                       NaN
# 25529                                         NaN                       NaN
# 25530                                         NaN                       NaN
#
#        Explained by: Perceptions of corruption  Dystopia + residual  \
# 0                                         0.01                1.895
# 1                                         0.01                1.895
# 2                                         0.01                1.895
# 3                                         0.01                1.895
# 4                                         0.01                1.895
# ...                                        ...                  ...
# 25526                                      NaN                  NaN
# 25527                                      NaN                  NaN
# 25528                                      NaN                  NaN
# 25529                                      NaN                  NaN
# 25530                                      NaN                  NaN
#
#        Regional_indicator  year  month  Regional_indicator_  \
# 0              South Asia  2020      2                  NaN
# 1              South Asia  2020      2                  NaN
# 2              South Asia  2020      2                  NaN
# 3              South Asia  2020      2                  NaN
# 4              South Asia  2020      2                  NaN
# ...                   ...   ...    ...                  ...
# 25526          South Asia  2022      6                  NaN
# 25527          South Asia  2022      6                  NaN
# 25528          South Asia  2022      6                  NaN
# 25529          South Asia  2022      6                  NaN
# 25530          South Asia  2022      6                  NaN
#
#        Regional_indicator_id  region
# 0                          3      SA
# 1                          3      SA
# 2                          3      SA
# 3                          3      SA
# 4                          3      SA
# ...                      ...     ...
# 25526                      3      SA
# 25527                      3      SA
# 25528                      3      SA
# 25529                      3      SA
# 25530                      3      SA
#
# [6000 rows x 92 columns]

# %%
dff = df.groupby(by=['Regional_indicator',"location"])['region','total_cases','total_deaths','gdp_per_capita','population', 'people_fully_vaccinated'].max().reset_index()

dff
# Out:
# <ipython-input-45-2151bf08855b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dff = df.groupby(by=['Regional_indicator',"location"])['region','total_cases','total_deaths','gdp_per_capita','population', 'people_fully_vaccinated'].max().reset_index()
#                     Regional_indicator              location region  \
# 0   Commonwealth of Independent States               Armenia   CWIS
# 1   Commonwealth of Independent States            Azerbaijan   CWIS
# 2   Commonwealth of Independent States               Georgia   CWIS
# 3   Commonwealth of Independent States            Kazakhstan   CWIS
# 4   Commonwealth of Independent States            Kyrgyzstan   CWIS
# 5   Commonwealth of Independent States            Tajikistan   CWIS
# 6   Commonwealth of Independent States          Turkmenistan   CWIS
# 7   Commonwealth of Independent States            Uzbekistan   CWIS
# 8                            East Asia                 China     EA
# 9                            East Asia             Hong Kong     EA
# 10                           East Asia                 Japan     EA
# 11                           East Asia                 Macao     EA
# 12                           East Asia              Mongolia     EA
# 13                           East Asia           North Korea     EA
# 14                           East Asia           South Korea     EA
# 15                           East Asia                Taiwan     EA
# 16        Middle East and North Africa               Bahrain     ME
# 17        Middle East and North Africa                  Iran     ME
# 18        Middle East and North Africa                  Iraq     ME
# 19        Middle East and North Africa                Israel     ME
# 20        Middle East and North Africa                Jordan     ME
# 21        Middle East and North Africa                Kuwait     ME
# 22        Middle East and North Africa               Lebanon     ME
# 23        Middle East and North Africa                  Oman     ME
# 24        Middle East and North Africa             Palestine     ME
# 25        Middle East and North Africa          Saudi Arabia     ME
# 26        Middle East and North Africa                 Syria     ME
# 27        Middle East and North Africa                Turkey     ME
# 28        Middle East and North Africa  United Arab Emirates     ME
# 29        Middle East and North Africa                 Yemen     ME
# 30                          South Asia           Afghanistan     SA
# 31                          South Asia            Bangladesh     SA
# 32                          South Asia                Bhutan     SA
# 33                          South Asia                 India     SA
# 34                          South Asia              Maldives     SA
# 35                          South Asia                 Nepal     SA
# 36                          South Asia              Pakistan     SA
# 37                          South Asia             Sri Lanka     SA
# 38                      Southeast Asia                Brunei    SEA
# 39                      Southeast Asia              Cambodia    SEA
# 40                      Southeast Asia             Indonesia    SEA
# 41                      Southeast Asia                  Laos    SEA
# 42                      Southeast Asia              Malaysia    SEA
# 43                      Southeast Asia               Myanmar    SEA
# 44                      Southeast Asia           Philippines    SEA
# 45                      Southeast Asia             Singapore    SEA
# 46                      Southeast Asia              Thailand    SEA
# 47                      Southeast Asia                 Timor    SEA
# 48                      Southeast Asia               Vietnam    SEA
#
#     total_cases  total_deaths  gdp_per_capita    population  \
# 0      445881.0        8712.0        8787.580  2.780472e+06
# 16             1.226796e+06
# 17             5.850896e+07
# 18             7.938409e+06
# 19             6.157274e+06
# 20             4.558313e+06
# 21             3.342954e+06
# 22             2.413718e+06
# 23             3.048826e+06
# 24             1.776973e+06
# 25             2.535168e+07
# 26             2.105113e+06
# 27             5.317696e+07
# 28             9.792266e+06
# 29             7.576690e+05
# 30             1.061563e+07
# 31             1.256706e+08
# 32             6.776690e+05
# 33             9.510424e+08
# 34             3.850760e+05
# 35             2.394922e+07
# 36             1.323177e+08
# 37             1.475283e+07
# 38             4.459290e+05
# 39             1.459410e+07
# 40             1.722985e+08
# 41             5.222417e+06
# 42             2.753000e+07
# 43             2.754533e+07
# 44             7.376273e+07
# 45             5.115779e+06
# 46             5.348609e+07
# 47             7.808900e+05
# 48             8.523915e+07

# %%
# dff = dff.drop([6,13])
grouped_region_data = dff
grouped_region_data
# Out:
#                     Regional_indicator              location region  \
# 0   Commonwealth of Independent States               Armenia   CWIS
# 1   Commonwealth of Independent States            Azerbaijan   CWIS
# 2   Commonwealth of Independent States               Georgia   CWIS
# 3   Commonwealth of Independent States            Kazakhstan   CWIS
# 4   Commonwealth of Independent States            Kyrgyzstan   CWIS
# 5   Commonwealth of Independent States            Tajikistan   CWIS
# 7   Commonwealth of Independent States            Uzbekistan   CWIS
# 8                            East Asia                 China     EA
# 9                            East Asia             Hong Kong     EA
# 10                           East Asia                 Japan     EA
# 11                           East Asia                 Macao     EA
# 12                           East Asia              Mongolia     EA
# 14                           East Asia           South Korea     EA
# 15                           East Asia                Taiwan     EA
# 16        Middle East and North Africa               Bahrain     ME
# 17        Middle East and North Africa                  Iran     ME
# 18        Middle East and North Africa                  Iraq     ME
# 19        Middle East and North Africa                Israel     ME
# 20        Middle East and North Africa                Jordan     ME
# 21        Middle East and North Africa                Kuwait     ME
# 22        Middle East and North Africa               Lebanon     ME
# 23        Middle East and North Africa                  Oman     ME
# 24        Middle East and North Africa             Palestine     ME
# 25        Middle East and North Africa          Saudi Arabia     ME
# 26        Middle East and North Africa                 Syria     ME
# 27        Middle East and North Africa                Turkey     ME
# 28        Middle East and North Africa  United Arab Emirates     ME
# 29        Middle East and North Africa                 Yemen     ME
# 30                          South Asia           Afghanistan     SA
# 31                          South Asia            Bangladesh     SA
# 32                          South Asia                Bhutan     SA
# 33                          South Asia                 India     SA
# 34                          South Asia              Maldives     SA
# 35                          South Asia                 Nepal     SA
# 36                          South Asia              Pakistan     SA
# 37                          South Asia             Sri Lanka     SA
# 38                      Southeast Asia                Brunei    SEA
# 39                      Southeast Asia              Cambodia    SEA
# 40                      Southeast Asia             Indonesia    SEA
# 41                      Southeast Asia                  Laos    SEA
# 42                      Southeast Asia              Malaysia    SEA
# 43                      Southeast Asia               Myanmar    SEA
# 44                      Southeast Asia           Philippines    SEA
# 45                      Southeast Asia             Singapore    SEA
# 46                      Southeast Asia              Thailand    SEA
# 47                      Southeast Asia                 Timor    SEA
# 48                      Southeast Asia               Vietnam    SEA
#
# 18             7.938409e+06
# 19             6.157274e+06
# 20             4.558313e+06
# 21             3.342954e+06
# 22             2.413718e+06
# 23             3.048826e+06
# 24             1.776973e+06
# 25             2.535168e+07
# 26             2.105113e+06
# 27             5.317696e+07
# 28             9.792266e+06
# 29             7.576690e+05
# 30             1.061563e+07
# 31             1.256706e+08
# 32             6.776690e+05
# 33             9.510424e+08
# 34             3.850760e+05
# 35             2.394922e+07
# 36             1.323177e+08
# 37             1.475283e+07
# 38             4.459290e+05
# 39             1.459410e+07
# 40             1.722985e+08
# 41             5.222417e+06
# 42             2.753000e+07
# 43             2.754533e+07
# 44             7.376273e+07
# 45             5.115779e+06
# 46             5.348609e+07
# 47             7.808900e+05
# 48             8.523915e+07

# %%
grouped_region_data['ratio_total_cases'] = grouped_region_data['total_cases']/grouped_region_data['population'] * 100
grouped_region_data['ratio_total_deaths'] = grouped_region_data['total_deaths']/grouped_region_data['population'] * 100
grouped_region_data['ratio_total_vaccinations'] = grouped_region_data['people_fully_vaccinated']/grouped_region_data['population'] * 100

grouped_region_data
# Out:
#                     Regional_indicator              location region  \
# 0   Commonwealth of Independent States               Armenia   CWIS
# 1   Commonwealth of Independent States            Azerbaijan   CWIS
# 2   Commonwealth of Independent States               Georgia   CWIS
# 3   Commonwealth of Independent States            Kazakhstan   CWIS
# 4   Commonwealth of Independent States            Kyrgyzstan   CWIS
# 5   Commonwealth of Independent States            Tajikistan   CWIS
# 7   Commonwealth of Independent States            Uzbekistan   CWIS
# 8                            East Asia                 China     EA
# 9                            East Asia             Hong Kong     EA
# 10                           East Asia                 Japan     EA
# 11                           East Asia                 Macao     EA
# 12                           East Asia              Mongolia     EA
# 14                           East Asia           South Korea     EA
# 15                           East Asia                Taiwan     EA
# 16        Middle East and North Africa               Bahrain     ME
# 17        Middle East and North Africa                  Iran     ME
# 18        Middle East and North Africa                  Iraq     ME
# 19        Middle East and North Africa                Israel     ME
# 20        Middle East and North Africa                Jordan     ME
# 21        Middle East and North Africa                Kuwait     ME
# 22        Middle East and North Africa               Lebanon     ME
# 23        Middle East and North Africa                  Oman     ME
# 24        Middle East and North Africa             Palestine     ME
# 25        Middle East and North Africa          Saudi Arabia     ME
# 26        Middle East and North Africa                 Syria     ME
# 27        Middle East and North Africa                Turkey     ME
# 28        Middle East and North Africa  United Arab Emirates     ME
# 29        Middle East and North Africa                 Yemen     ME
# 30                          South Asia           Afghanistan     SA
# 31                          South Asia            Bangladesh     SA
# 32                          South Asia                Bhutan     SA
# 33                          South Asia                 India     SA
# 34                          South Asia              Maldives     SA
# 35                          South Asia                 Nepal     SA
# 36                          South Asia              Pakistan     SA
# 37                          South Asia             Sri Lanka     SA
# 38                      Southeast Asia                Brunei    SEA
# 39                      Southeast Asia              Cambodia    SEA
# 40                      Southeast Asia             Indonesia    SEA
# 41                      Southeast Asia                  Laos    SEA
# 42                      Southeast Asia              Malaysia    SEA
# 43                      Southeast Asia               Myanmar    SEA
# 44                      Southeast Asia           Philippines    SEA
# 4              1.359470e+06           3.115198            0.045109
# 5              5.120562e+06           0.178704            0.001256
# 7              1.752908e+07           0.719209            0.004727
# 8              1.274018e+09           0.133945            0.000389
# 9              6.781912e+06          32.077473            0.151345
# 10             1.030876e+08          22.269602            0.043593
# 11             6.293610e+05           0.225697            0.001870
# 12             2.175617e+06          29.639183            0.062824
# 14             4.470857e+07          54.937655            0.061006
# 15             2.060885e+07          36.096501            0.062758
# 16             1.226796e+06          47.412747            0.104535
# 17             5.850896e+07           8.538205            0.163378
# 18             7.938409e+06           5.540049            0.057023
# 19             6.157274e+06          50.295767            0.126796
# 20             4.558313e+06          15.479500            0.125130
# 21             3.342954e+06          15.525057            0.060203
# 22             2.413718e+06          22.255883            0.195692
# 23             3.048826e+06           8.722199            0.101130
# 24             1.776973e+06          13.394625            0.108722
# 25             2.535168e+07           2.270513            0.026098
# 26             2.105113e+06           0.259536            0.014296
# 27             5.317696e+07          19.825862            0.118586
# 28             9.792266e+06          11.082975            0.024870
# 29             7.576690e+05           0.035449            0.006407
# 30             1.061563e+07           0.503759            0.019074
# 31             1.256706e+08           1.189924            0.017196
# 32             6.776690e+05           7.990727            0.002684
# 33             9.510424e+08           3.152596            0.037446
# 34             3.850760e+05          35.446107            0.059374
# 35             2.394922e+07           3.276727            0.039345
# 36             1.323177e+08           0.668075            0.012991
# 37             1.475283e+07           3.077255            0.077015
# 38             4.459290e+05          59.424902            0.050111
# 39             1.459410e+07           0.825729            0.018225
# 40             1.722985e+08           2.436586            0.058245
# 41             5.222417e+06           2.889789            0.010067
# 42             2.753000e+07          14.792716            0.108494
# 43             2.754533e+07           1.169422            0.035971
# 44             7.376273e+07           3.512028            0.056371
# 45             5.115779e+06          38.898021            0.030335
# 46             5.348609e+07           6.581735            0.046731
# 47             7.808900e+05           1.743535            0.010289
# 48             8.523915e+07          11.736364            0.043978
#
#     ratio_total_vaccinations
# 0                  35.454664
# 1                  46.943979
# 2                  34.082313
# 3                  54.715719
# 4                  20.502906
# 5                  51.448514
# 7                  50.621625
# 8                  89.349133
# 9                  90.559969
# 10                 83.167544
# 11                 90.532092
# 12                 64.019370
# 14                 86.283641
# 15                 86.253327
# 16                 83.328703
# 17                 66.074064
# 18                 17.840675
# 19                 65.163234
# 20                 40.389540
# 21                 78.309751
# 22                 43.967770
# 23                 66.622075
# 24                 33.846615
# 25                 69.630601
# 26                  9.514531
# 27                 62.310972
# 28                103.719128
# 29                  2.248502
# 30                 25.810710
# 31                 73.411586
# 32                 86.607826
# 33                 67.108417
# 34                 73.516126
# 35                 78.399730
# 36                 56.108476
# 37                 67.573862
# 38                 99.315593
# 39                 87.036192
# 40                 62.539991
# 41                 69.359625
# 42                 81.117982
# 43                 50.841046
# 44                 63.831226
# 45                 90.753220
# 46                 74.600148
# 47                 58.218979
# 48                 86.813199

# %%
grouped_region_data.to_csv(r'C:\Users\Kozy-Korpesh\Desktop\unige 2 course\dv\final Urwa\data\buble_data.csv',index=False,header=True)
