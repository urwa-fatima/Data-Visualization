# %%
# !pip install geopandas

# %%
# !pip install matplotlib

# %%
# %pip install pygeos

# %%
# %pip install rtree

# %%
# All the import Libraries
import pandas as pd
import geopandas as gp
from matplotlib.patches import Polygon
import matplotlib.pyplot as plt

# %%
# read files
data = gp.read_file("../data/geo_data_trees.geojson")
polydata = gp.read_file("../data/circoscrizioni.json")

# %%
print(polydata.crs)
polydata.head(2)
# Out:
# epsg:4326
#    numero_cir      area  perimetro     nome                        fumetto  \
# 0           2  15712181      17850    MEANO    Circoscrizione n. 2 - MEANO
# 1           3  36949609      38485  BONDONE  Circoscrizione n. 3 - BONDONE
#
#                                             geometry
# 0  POLYGON ((11.15678 46.11661, 11.15687 46.11666...
# 1  POLYGON ((11.08026 46.11571, 11.08026 46.11571...

# %% [markdown]
# # Calculating area using geopandas.area

# %%
polydata_copy = polydata.copy()
polydata_copy= polydata_copy.to_crs({'init': 'epsg:32633'})
print(polydata_copy.crs)
polydata_copy["area(m2)"] = polydata_copy['geometry'].area
polydata_copy.head(10)
# Out:
# +init=epsg:32633 +type=crs
# C:\Users\Kozy-Korpesh\anaconda3\lib\site-packages\pyproj\crs\crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#    numero_cir      area  perimetro                 nome  \
# 0           2  15712181      17850                MEANO
# 1           3  36949609      38485              BONDONE
# 2           4   8663138      16403             SARDAGNA
# 3           6  13199398      20575           ARGENTARIO
# 4          11   3073349      10962  S.GIUSEPPE-S.CHIARA
# 5           7  15433274      18464                 POVO
# 6           5  16687779      27197     RAVINA-ROMAGNANO
# 7           8  16409555      24413           MATTARELLO
# 8           9   7342864      15395           VILLAZZANO
# 9          10   6962104      15418         OLTREFERSINA
#
#                                       fumetto  \
# 0                 Circoscrizione n. 2 - MEANO
# 1               Circoscrizione n. 3 - BONDONE
# 2              Circoscrizione n. 4 - SARDAGNA
# 3            Circoscrizione n. 6 - ARGENTARIO
# 4  Circoscrizione n. 11 - S.GIUSEPPE-S.CHIARA
# 5                  Circoscrizione n. 7 - POVO
# 6      Circoscrizione n. 5 - RAVINA-ROMAGNANO
# 7            Circoscrizione n. 8 - MATTARELLO
# 8            Circoscrizione n. 9 - VILLAZZANO
# 9         Circoscrizione n. 10 - OLTREFERSINA
#
#                                             geometry      area(m2)
# 0  POLYGON ((203044.805 5114187.221, 203051.692 5...  1.573604e+07
# 1  POLYGON ((197127.561 5114376.228, 197127.561 5...  3.701146e+07
# 2  POLYGON ((197706.671 5110278.623, 197704.201 5...  8.677127e+06
# 3  POLYGON ((204000.910 5110170.320, 203999.958 5...  1.321934e+07
# 4  POLYGON ((199220.493 5107933.053, 199221.348 5...  3.078116e+06
# 5  POLYGON ((204734.917 5104413.406, 204735.120 5...  1.545520e+07
# 6  POLYGON ((199192.520 5100133.847, 199198.110 5...  1.671439e+07
# 7  POLYGON ((199192.520 5100133.847, 199231.881 5...  1.642222e+07
# 8  POLYGON ((202529.680 5103085.363, 202543.660 5...  7.347780e+06
# 9  POLYGON ((199591.347 5106192.940, 199613.636 5...  6.972767e+06

# %%
data
# Out:
#        Tree ID                    Name DBH (cm) Replacement Value (eur)  \
# 0          1.0     Acer pseudoplatanus        8                  179.43
# 1          2.0     Acer pseudoplatanus        8                  179.43
# 2          3.0     Acer pseudoplatanus        9                  227.09
# 3          4.0     Acer pseudoplatanus       11                  482.46
# 4          7.0               Cupressus       25                 1110.29
# ...        ...                     ...      ...                     ...
# 12508  17664.0            Philadelphus     28.2                  1354.8
# 12509  17665.0  Forsythia x intermedia     28.2                  1354.8
# 12510  17666.0         Aucuba japonica     28.2                  1354.8
# 12511  17667.0      Osmanthus fragrans     28.2                  1354.8
# 12512      NaN                   Total     None                23086243
#
#       Carbon Storage (kg) Carbon Storage (eur)  \
# 0                      12                 1.92
# 1                    12.9                 2.07
# 2                    16.2                 2.61
# 3                    25.7                 4.13
# 4                   448.2                72.02
# ...                   ...                  ...
# 12508               396.2                63.66
# 12509               320.9                51.56
# 12510               356.2                57.22
# 12511               240.7                38.67
# 12512             5484735               881216
#
#       Gross Carbon Sequestration (kg/yr) Gross Carbon Sequestration (eur/yr)  \
# 0                                    1.1                                0.17
# 1                                    1.1                                0.18
# 2                                    1.3                                 0.2
# 3                                    1.6                                0.26
# 4                                   11.1                                1.78
# ...                                  ...                                 ...
# 12508                               10.7                                1.71
# 12509                               10.5                                1.68
# 12510                                6.3                                1.01
# 12511                                4.3                  0.6899999999999999
# 12512                              71714                               11522
#
#       Avoided Runoff (mcube/yr) Avoided Runoff (eur/yr)  ...  \
# 0                             0                    0.01  ...
# 1                             0                    0.01  ...
# 2                             0                    0.01  ...
# 3                             0                    0.02  ...
# 4                             0                    0.02  ...
# ...                         ...                     ...  ...
# 12508                       0.1                    0.13  ...
# 12509                       0.1                    0.21  ...
# 12510                       0.1                    0.14  ...
# 12511                       0.1                    0.15  ...
# 12512                      2270                    4317  ...
#
#       Oxygen Production (kg/yr) Height (m) Crown Height (m) Crown Width (m)  \
# 0                           2.8        3.5                1             1.5
# 1                             3          5              1.5             1.5
# 2                           3.4        4.5              1.3             1.5
# 3                           4.3          5              1.5             2.5
# 4                          29.5          8              2.4             1.5
# ...                         ...        ...              ...             ...
# 12508                      28.4        2.5              0.8             5.3
# 12509                      27.9          8              2.4             5.3
# 12510                      16.7          8              2.4             5.3
# 12511                      11.5        2.5              0.8             5.3
# 12512                  191237.8       None             None            None
#
#       Canopy Cover (m2) Leaf Area (m2) Leaf Biomass (kg)   Latitude  \
# 0                   1.8            3.5               0.2  46.051599
# 1                   1.8            4.2               0.3  46.051541
# 2                   1.8              4               0.3  46.051668
# 3                   4.9            7.1               0.5  46.063778
# 4                   1.8            6.6               1.5  46.052305
# ...                 ...            ...               ...        ...
# 12508              21.7           36.1               2.7  46.055851
# 12509              21.7           59.9               4.6  46.055402
# 12510              21.7           41.3               2.5  46.055867
# 12511              21.7           43.3               3.8  46.053467
# 12512          382146.7      1241575.9          101770.6        NaN
#
#        Longitude                   geometry
# 0      11.072014  POINT (11.07201 46.05160)
# 1      11.072108  POINT (11.07211 46.05154)
# 2      11.071959  POINT (11.07196 46.05167)
# 3      11.150170  POINT (11.15017 46.06378)
# 4      11.071550  POINT (11.07155 46.05230)
# ...          ...                        ...
# 12508  11.129388  POINT (11.12939 46.05585)
# 12509  11.129206  POINT (11.12921 46.05540)
# 12510  11.129650  POINT (11.12965 46.05587)
# 12511  11.121152  POINT (11.12115 46.05347)
# 12512        NaN                       None
#
# [12513 rows x 26 columns]

# %%
# %matplotlib inline
data.plot()
# Out:
# <AxesSubplot:>

# %%
polydata_copy
# Out:
#     numero_cir      area  perimetro                          nome  \
# 0            2  15712181      17850                         MEANO
# 1            3  36949609      38485                       BONDONE
# 2            4   8663138      16403                      SARDAGNA
# 3            6  13199398      20575                    ARGENTARIO
# 4           11   3073349      10962           S.GIUSEPPE-S.CHIARA
# 5            7  15433274      18464                          POVO
# 6            5  16687779      27197              RAVINA-ROMAGNANO
# 7            8  16409555      24413                    MATTARELLO
# 8            9   7342864      15395                    VILLAZZANO
# 9           10   6962104      15418                  OLTREFERSINA
# 10           1   8817959      14719                       GARDOLO
# 11          12   8599464      23151  CENTRO STORICO PIEDICASTELLO
#
#                                               fumetto  \
# 0                         Circoscrizione n. 2 - MEANO
# 1                       Circoscrizione n. 3 - BONDONE
# 2                      Circoscrizione n. 4 - SARDAGNA
# 3                    Circoscrizione n. 6 - ARGENTARIO
# 4          Circoscrizione n. 11 - S.GIUSEPPE-S.CHIARA
# 5                          Circoscrizione n. 7 - POVO
# 6              Circoscrizione n. 5 - RAVINA-ROMAGNANO
# 7                    Circoscrizione n. 8 - MATTARELLO
# 8                    Circoscrizione n. 9 - VILLAZZANO
# 9                 Circoscrizione n. 10 - OLTREFERSINA
# 10                      Circoscrizione n. 1 - GARDOLO
# 11  Circoscrizione n. 12 - CENTRO STORICO PIEDICAS...
#
#                                              geometry      area(m2)
# 0   POLYGON ((203044.805 5114187.221, 203051.692 5...  1.573604e+07
# 1   POLYGON ((197127.561 5114376.228, 197127.561 5...  3.701146e+07
# 2   POLYGON ((197706.671 5110278.623, 197704.201 5...  8.677127e+06
# 3   POLYGON ((204000.910 5110170.320, 203999.958 5...  1.321934e+07
# 4   POLYGON ((199220.493 5107933.053, 199221.348 5...  3.078116e+06
# 5   POLYGON ((204734.917 5104413.406, 204735.120 5...  1.545520e+07
# 6   POLYGON ((199192.520 5100133.847, 199198.110 5...  1.671439e+07
# 7   POLYGON ((199192.520 5100133.847, 199231.881 5...  1.642222e+07
# 8   POLYGON ((202529.680 5103085.363, 202543.660 5...  7.347780e+06
# 9   POLYGON ((199591.347 5106192.940, 199613.636 5...  6.972767e+06
# 10  POLYGON ((199864.503 5113510.249, 199857.577 5...  8.831921e+06
# 11  POLYGON ((200620.911 5109775.248, 200603.327 5...  8.613014e+06

# %%
polydata_copy.plot()
# Out:
# <AxesSubplot:>

# %%
# 12513 rows × 26 columns
# Basic information about all the columns of the data
data.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 12513 entries, 0 to 12512
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Tree ID                              12512 non-null  float64
#  1   Name                                 12513 non-null  object
#  2   DBH (cm)                             12512 non-null  object
#  3   Replacement Value (eur)              12513 non-null  object
#  4   Carbon Storage (kg)                  12513 non-null  object
#  5   Carbon Storage (eur)                 12513 non-null  object
#  6   Gross Carbon Sequestration (kg/yr)   12513 non-null  object
#  7   Gross Carbon Sequestration (eur/yr)  12513 non-null  object
#  8   Avoided Runoff (mcube/yr)            12513 non-null  object
#  9   Avoided Runoff (eur/yr)              12513 non-null  object
#  10  Carbon Avoided (kg/yr)               0 non-null      object
#  11  Carbon Avoided (eur/yr)              0 non-null      object
#  12  Pollution Removal (g/yr)             12513 non-null  object
#  13  Pollution Removal (eur/yr)           12513 non-null  object
#  14  Energy Savings (eur/yr)              0 non-null      object
#  15  Total Annual Benefits (eur/yr)       12513 non-null  object
#  16  Oxygen Production (kg/yr)            12513 non-null  object
#  17  Height (m)                           12512 non-null  object
#  18  Crown Height (m)                     12512 non-null  object
#  19  Crown Width (m)                      12512 non-null  object
#  20  Canopy Cover (m2)                    12513 non-null  object
#  21  Leaf Area (m2)                       12513 non-null  object
#  22  Leaf Biomass (kg)                    12513 non-null  object
#  23  Latitude                             12512 non-null  float64
#  24  Longitude                            12512 non-null  float64
#  25  geometry                             12512 non-null  geometry
# dtypes: float64(3), geometry(1), object(22)
# memory usage: 2.5+ MB

# %%
data.tail()
# Out:
#        Tree ID                    Name DBH (cm) Replacement Value (eur)  \
# 12508  17664.0            Philadelphus     28.2                  1354.8
# 12509  17665.0  Forsythia x intermedia     28.2                  1354.8
# 12510  17666.0         Aucuba japonica     28.2                  1354.8
# 12511  17667.0      Osmanthus fragrans     28.2                  1354.8
# 12512      NaN                   Total     None                23086243
#
#       Carbon Storage (kg) Carbon Storage (eur)  \
# 12508               396.2                63.66
# 12509               320.9                51.56
# 12510               356.2                57.22
# 12511               240.7                38.67
# 12512             5484735               881216
#
#       Gross Carbon Sequestration (kg/yr) Gross Carbon Sequestration (eur/yr)  \
# 12508                               10.7                                1.71
# 12509                               10.5                                1.68
# 12510                                6.3                                1.01
# 12511                                4.3                  0.6899999999999999
# 12512                              71714                               11522
#
#       Avoided Runoff (mcube/yr) Avoided Runoff (eur/yr)  ...  \
# 12508                       0.1                    0.13  ...
# 12509                       0.1                    0.21  ...
# 12510                       0.1                    0.14  ...
# 12511                       0.1                    0.15  ...
# 12512                      2270                    4317  ...
#
#       Oxygen Production (kg/yr) Height (m) Crown Height (m) Crown Width (m)  \
# 12508                      28.4        2.5              0.8             5.3
# 12509                      27.9          8              2.4             5.3
# 12510                      16.7          8              2.4             5.3
# 12511                      11.5        2.5              0.8             5.3
# 12512                  191237.8       None             None            None
#
#       Canopy Cover (m2) Leaf Area (m2) Leaf Biomass (kg)   Latitude  \
# 12508              21.7           36.1               2.7  46.055851
# 12509              21.7           59.9               4.6  46.055402
# 12510              21.7           41.3               2.5  46.055867
# 12511              21.7           43.3               3.8  46.053467
# 12512          382146.7      1241575.9          101770.6        NaN
#
#        Longitude                   geometry
# 12508  11.129388  POINT (11.12939 46.05585)
# 12509  11.129206  POINT (11.12921 46.05540)
# 12510  11.129650  POINT (11.12965 46.05587)
# 12511  11.121152  POINT (11.12115 46.05347)
# 12512        NaN                       None
#
# [5 rows x 26 columns]

# %%
# deleting the last row
data = data.drop(data.index[-1])

# %%
# the last row is the total row for all the data so should be avoided 
# when including in the data values.
data.tail()
# Out:
#        Tree ID                    Name DBH (cm) Replacement Value (eur)  \
# 12507  17663.0            Philadelphus     28.2                  1354.8
# 12508  17664.0            Philadelphus     28.2                  1354.8
# 12509  17665.0  Forsythia x intermedia     28.2                  1354.8
# 12510  17666.0         Aucuba japonica     28.2                  1354.8
# 12511  17667.0      Osmanthus fragrans     28.2                  1354.8
#
#       Carbon Storage (kg) Carbon Storage (eur)  \
# 12507               396.2                63.66
# 12508               396.2                63.66
# 12509               320.9                51.56
# 12510               356.2                57.22
# 12511               240.7                38.67
#
#       Gross Carbon Sequestration (kg/yr) Gross Carbon Sequestration (eur/yr)  \
# 12507                               10.7                                1.71
# 12508                               10.7                                1.71
# 12509                               10.5                                1.68
# 12510                                6.3                                1.01
# 12511                                4.3                  0.6899999999999999
#
#       Avoided Runoff (mcube/yr) Avoided Runoff (eur/yr)  ...  \
# 12507                       0.1                    0.15  ...
# 12508                       0.1                    0.13  ...
# 12509                       0.1                    0.21  ...
# 12510                       0.1                    0.14  ...
# 12511                       0.1                    0.15  ...
#
#       Oxygen Production (kg/yr) Height (m) Crown Height (m) Crown Width (m)  \
# 12507                      28.4        2.5              0.8             5.3
# 12508                      28.4        2.5              0.8             5.3
# 12509                      27.9          8              2.4             5.3
# 12510                      16.7          8              2.4             5.3
# 12511                      11.5        2.5              0.8             5.3
#
#       Canopy Cover (m2) Leaf Area (m2) Leaf Biomass (kg)   Latitude  \
# 12507              21.7           43.6               3.3  46.055912
# 12508              21.7           36.1               2.7  46.055851
# 12509              21.7           59.9               4.6  46.055402
# 12510              21.7           41.3               2.5  46.055867
# 12511              21.7           43.3               3.8  46.053467
#
#        Longitude                   geometry
# 12507  11.129441  POINT (11.12944 46.05591)
# 12508  11.129388  POINT (11.12939 46.05585)
# 12509  11.129206  POINT (11.12921 46.05540)
# 12510  11.129650  POINT (11.12965 46.05587)
# 12511  11.121152  POINT (11.12115 46.05347)
#
# [5 rows x 26 columns]

# %%
print(polydata_copy["geometry"])
# Out:
# 0     POLYGON ((203044.805 5114187.221, 203051.692 5...
# 1     POLYGON ((197127.561 5114376.228, 197127.561 5...
# 2     POLYGON ((197706.671 5110278.623, 197704.201 5...
# 3     POLYGON ((204000.910 5110170.320, 203999.958 5...
# 4     POLYGON ((199220.493 5107933.053, 199221.348 5...
# 5     POLYGON ((204734.917 5104413.406, 204735.120 5...
# 6     POLYGON ((199192.520 5100133.847, 199198.110 5...
# 7     POLYGON ((199192.520 5100133.847, 199231.881 5...
# 8     POLYGON ((202529.680 5103085.363, 202543.660 5...
# 9     POLYGON ((199591.347 5106192.940, 199613.636 5...
# 10    POLYGON ((199864.503 5113510.249, 199857.577 5...
# 11    POLYGON ((200620.911 5109775.248, 200603.327 5...
# Name: geometry, dtype: geometry

# %%
# Group the data by column 
grouped = data.groupby('Name')

# Let's see what we have
grouped

# %%
grouped.head()
# Out:
#        Tree ID                    Name DBH (cm) Replacement Value (eur)  \
# 0          1.0     Acer pseudoplatanus        8                  179.43
# 1          2.0     Acer pseudoplatanus        8                  179.43
# 2          3.0     Acer pseudoplatanus        9                  227.09
# 3          4.0     Acer pseudoplatanus       11                  482.46
# 4          7.0               Cupressus       25                 1110.29
# ...        ...                     ...      ...                     ...
# 12507  17663.0            Philadelphus     28.2                  1354.8
# 12508  17664.0            Philadelphus     28.2                  1354.8
# 12509  17665.0  Forsythia x intermedia     28.2                  1354.8
# 12510  17666.0         Aucuba japonica     28.2                  1354.8
# 12511  17667.0      Osmanthus fragrans     28.2                  1354.8
#
#       Carbon Storage (kg) Carbon Storage (eur)  \
# 0                      12                 1.92
# 1                    12.9                 2.07
# 2                    16.2                 2.61
# 3                    25.7                 4.13
# 4                   448.2                72.02
# ...                   ...                  ...
# 12507               396.2                63.66
# 12508               396.2                63.66
# 12509               320.9                51.56
# 12510               356.2                57.22
# 12511               240.7                38.67
#
#       Gross Carbon Sequestration (kg/yr) Gross Carbon Sequestration (eur/yr)  \
# 0                                    1.1                                0.17
# 1                                    1.1                                0.18
# 2                                    1.3                                 0.2
# 3                                    1.6                                0.26
# 4                                   11.1                                1.78
# ...                                  ...                                 ...
# 12507                               10.7                                1.71
# 12508                               10.7                                1.71
# 12509                               10.5                                1.68
# 12510                                6.3                                1.01
# 12511                                4.3                  0.6899999999999999
#
#       Avoided Runoff (mcube/yr) Avoided Runoff (eur/yr)  ...  \
# 0                             0                    0.01  ...
# 1                             0                    0.01  ...
# 2                             0                    0.01  ...
# 3                             0                    0.02  ...
# 4                             0                    0.02  ...
# ...                         ...                     ...  ...
# 12507                       0.1                    0.15  ...
# 12508                       0.1                    0.13  ...
# 12509                       0.1                    0.21  ...
# 12510                       0.1                    0.14  ...
# 12511                       0.1                    0.15  ...
#
#       Oxygen Production (kg/yr) Height (m) Crown Height (m) Crown Width (m)  \
# 0                           2.8        3.5                1             1.5
# 1                             3          5              1.5             1.5
# 2                           3.4        4.5              1.3             1.5
# 3                           4.3          5              1.5             2.5
# 4                          29.5          8              2.4             1.5
# ...                         ...        ...              ...             ...
# 12507                      28.4        2.5              0.8             5.3
# 12508                      28.4        2.5              0.8             5.3
# 12509                      27.9          8              2.4             5.3
# 12510                      16.7          8              2.4             5.3
# 12511                      11.5        2.5              0.8             5.3
#
#       Canopy Cover (m2) Leaf Area (m2) Leaf Biomass (kg)   Latitude  \
# 0                   1.8            3.5               0.2  46.051599
# 1                   1.8            4.2               0.3  46.051541
# 2                   1.8              4               0.3  46.051668
# 3                   4.9            7.1               0.5  46.063778
# 4                   1.8            6.6               1.5  46.052305
# ...                 ...            ...               ...        ...
# 12507              21.7           43.6               3.3  46.055912
# 12508              21.7           36.1               2.7  46.055851
# 12509              21.7           59.9               4.6  46.055402
# 12510              21.7           41.3               2.5  46.055867
# 12511              21.7           43.3               3.8  46.053467
#
#        Longitude                   geometry
# 0      11.072014  POINT (11.07201 46.05160)
# 1      11.072108  POINT (11.07211 46.05154)
# 2      11.071959  POINT (11.07196 46.05167)
# 3      11.150170  POINT (11.15017 46.06378)
# 4      11.071550  POINT (11.07155 46.05230)
# ...          ...                        ...
# 12507  11.129441  POINT (11.12944 46.05591)
# 12508  11.129388  POINT (11.12939 46.05585)
# 12509  11.129206  POINT (11.12921 46.05540)
# 12510  11.129650  POINT (11.12965 46.05587)
# 12511  11.121152  POINT (11.12115 46.05347)
#
# [897 rows x 26 columns]

# %%
data["Canopy Cover (m2)"]
# Out:
# 0         1.8
# 1         1.8
# 2         1.8
# 3         4.9
# 4         1.8
#          ...
# 12507    21.7
# 12508    21.7
# 12509    21.7
# 12510    21.7
# 12511    21.7
# Name: Canopy Cover (m2), Length: 12512, dtype: object

# %%
data['canopy_cov'] = data['Canopy Cover (m2)'].astype(float)

# %%
data['canopy_cov']
# Out:
# 0         1.8
# 1         1.8
# 2         1.8
# 3         4.9
# 4         1.8
#          ...
# 12507    21.7
# 12508    21.7
# 12509    21.7
# 12510    21.7
# 12511    21.7
# Name: canopy_cov, Length: 12512, dtype: float64

# %% [markdown]
# # Merging polygon and data

# %%
points = data["geometry"]

# %%
polydata['area(m2)'] = polydata_copy['area(m2)']

# %%
polydata[polydata.contains(points[0])]
# Out:
#    numero_cir     area  perimetro      nome                         fumetto  \
# 2           4  8663138      16403  SARDAGNA  Circoscrizione n. 4 - SARDAGNA
#
#                                             geometry      area(m2)
# 2  POLYGON ((11.09034 46.07917, 11.09032 46.07899...  8.677127e+06

# %%
join = gp.sjoin(data, polydata, how="inner", predicate="within")

# %%
join.rename(columns={'nome': 'Region'}, inplace=True)
join
# Out:
#        Tree ID                  Name DBH (cm) Replacement Value (eur)  \
# 0          1.0   Acer pseudoplatanus        8                  179.43
# 1          2.0   Acer pseudoplatanus        8                  179.43
# 2          3.0   Acer pseudoplatanus        9                  227.09
# 4          7.0             Cupressus       25                 1110.29
# 5          8.0   Acer pseudoplatanus        9                  227.09
# ...        ...                   ...      ...                     ...
# 12499  17655.0                 Picea     34.3                 2048.48
# 12503  17659.0               Spiraea     28.2                  1354.8
# 12504  17660.0  Rhododendron obtusum     28.2                  1354.8
# 12505  17661.0    Pittosporum tobira     28.2                  1354.8
# 12511  17667.0    Osmanthus fragrans     28.2                  1354.8
#
#       Carbon Storage (kg) Carbon Storage (eur)  \
# 0                      12                 1.92
# 1                    12.9                 2.07
# 2                    16.2                 2.61
# 4                   448.2                72.02
# 5                    16.2                 2.61
# ...                   ...                  ...
# 12499                 719               115.52
# 12503               396.2                63.66
# 12504               465.3                74.77
# 12505               396.4                63.69
# 12511               240.7                38.67
#
#       Gross Carbon Sequestration (kg/yr) Gross Carbon Sequestration (eur/yr)  \
# 0                                    1.1                                0.17
# 1                                    1.1                                0.18
# 2                                    1.3                                 0.2
# 4                                   11.1                                1.78
# 5                                    1.3                                 0.2
# ...                                  ...                                 ...
# 12499                               14.3                                 2.3
# 12503                               10.7                                1.71
# 12504                                8.5                                1.37
# 12505                                7.4                                1.19
# 12511                                4.3                  0.6899999999999999
#
#       Avoided Runoff (mcube/yr) Avoided Runoff (eur/yr)  ...  Longitude  \
# 0                             0                    0.01  ...  11.072014
# 1                             0                    0.01  ...  11.072108
# 2                             0                    0.01  ...  11.071959
# 4                             0                    0.02  ...  11.071550
# 5                             0                    0.01  ...  11.071766
# ...                         ...                     ...  ...        ...
# 12499                       0.1                    0.24  ...  11.121614
# 12503                       0.1                    0.14  ...  11.121604
# 12504                       0.1                    0.17  ...  11.119373
# 12505                         0                    0.02  ...  11.121107
# 12511                       0.1                    0.15  ...  11.121152
#
#                         geometry canopy_cov index_right numero_cir     area  \
# 0      POINT (11.07201 46.05160)        1.8           2          4  8663138
# 1      POINT (11.07211 46.05154)        1.8           2          4  8663138
# 2      POINT (11.07196 46.05167)        1.8           2          4  8663138
# 4      POINT (11.07155 46.05230)        1.8           2          4  8663138
# 5      POINT (11.07177 46.05200)        1.8           2          4  8663138
# ...                          ...        ...         ...        ...      ...
# 12499  POINT (11.12161 46.05350)       21.0           4         11  3073349
# 12503  POINT (11.12160 46.05350)       21.7           4         11  3073349
# 12504  POINT (11.11937 46.05563)       21.7           4         11  3073349
# 12505  POINT (11.12111 46.05346)        3.1           4         11  3073349
# 12511  POINT (11.12115 46.05347)       21.7           4         11  3073349
#
#       perimetro               Region  \
# 0         16403             SARDAGNA
# 1         16403             SARDAGNA
# 2         16403             SARDAGNA
# 4         16403             SARDAGNA
# 5         16403             SARDAGNA
# ...         ...                  ...
# 12499     10962  S.GIUSEPPE-S.CHIARA
# 12503     10962  S.GIUSEPPE-S.CHIARA
# 12504     10962  S.GIUSEPPE-S.CHIARA
# 12505     10962  S.GIUSEPPE-S.CHIARA
# 12511     10962  S.GIUSEPPE-S.CHIARA
#
#                                           fumetto      area(m2)
# 0                  Circoscrizione n. 4 - SARDAGNA  8.677127e+06
# 1                  Circoscrizione n. 4 - SARDAGNA  8.677127e+06
# 2                  Circoscrizione n. 4 - SARDAGNA  8.677127e+06
# 4                  Circoscrizione n. 4 - SARDAGNA  8.677127e+06
# 5                  Circoscrizione n. 4 - SARDAGNA  8.677127e+06
# ...                                           ...           ...
# 12499  Circoscrizione n. 11 - S.GIUSEPPE-S.CHIARA  3.078116e+06
# 12503  Circoscrizione n. 11 - S.GIUSEPPE-S.CHIARA  3.078116e+06
# 12504  Circoscrizione n. 11 - S.GIUSEPPE-S.CHIARA  3.078116e+06
# 12505  Circoscrizione n. 11 - S.GIUSEPPE-S.CHIARA  3.078116e+06
# 12511  Circoscrizione n. 11 - S.GIUSEPPE-S.CHIARA  3.078116e+06
#
# [12512 rows x 34 columns]

# %%
# join.to_csv (r'C:\Users\Kozy-Korpesh\Desktop\dv\Data-Visualization\data\merged_tree_and_region.csv', index = False, header=True)

# %%
stackeddata = join[["Name", "Region","numero_cir","canopy_cov","area(m2)"]]

# %%
stackeddata['density'] = 1
# Out:
# <ipython-input-30-caf25f436e35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stackeddata['density'] = 1

# %%
stackeddata
# Out:
#                        Name               Region  numero_cir  canopy_cov  \
# 0       Acer pseudoplatanus             SARDAGNA           4         1.8
# 1       Acer pseudoplatanus             SARDAGNA           4         1.8
# 2       Acer pseudoplatanus             SARDAGNA           4         1.8
# 4                 Cupressus             SARDAGNA           4         1.8
# 5       Acer pseudoplatanus             SARDAGNA           4         1.8
# ...                     ...                  ...         ...         ...
# 12499                 Picea  S.GIUSEPPE-S.CHIARA          11        21.0
# 12503               Spiraea  S.GIUSEPPE-S.CHIARA          11        21.7
# 12504  Rhododendron obtusum  S.GIUSEPPE-S.CHIARA          11        21.7
# 12505    Pittosporum tobira  S.GIUSEPPE-S.CHIARA          11         3.1
# 12511    Osmanthus fragrans  S.GIUSEPPE-S.CHIARA          11        21.7
#
#            area(m2)  density
# 0      8.677127e+06        1
# 1      8.677127e+06        1
# 2      8.677127e+06        1
# 4      8.677127e+06        1
# 5      8.677127e+06        1
# ...             ...      ...
# 12499  3.078116e+06        1
# 12503  3.078116e+06        1
# 12504  3.078116e+06        1
# 12505  3.078116e+06        1
# 12511  3.078116e+06        1
#
# [12512 rows x 6 columns]

# %%
grouped_region_data = stackeddata.groupby(['numero_cir','area(m2)'])['canopy_cov'].sum() #.sort_values(ascending=False) #.unstack().fillna(0)
grouped_region_data = grouped_region_data.reset_index()
grouped_region_data
# Out:
#     numero_cir      area(m2)  canopy_cov
# 0            1  8.831921e+06     27279.5
# 1            2  1.573604e+07      3136.1
# 2            3  3.701146e+07      5979.6
# 3            4  8.677127e+06       389.2
# 4            5  1.671439e+07      6289.5
# 5            6  1.321934e+07     12416.1
# 6            7  1.545520e+07      2866.9
# 7            8  1.642222e+07      4995.4
# 8            9  7.347780e+06      6352.5
# 9           10  6.972767e+06     87988.8
# 10          11  3.078116e+06     93333.1
# 11          12  8.613014e+06    131189.1

# %%
grouped_region_data['density'] = grouped_region_data['canopy_cov']/grouped_region_data['area(m2)']
# grouped_region_data = grouped_region_data.drop(['area(m2)','canopy_cov'],axis=1)

# %%
grouped_region_data = grouped_region_data.rename(columns={"numero_cir": "id","area(m2)":"area"})
grouped_region_data
# Out:
#     id          area  canopy_cov   density
# 0    1  8.831921e+06     27279.5  0.003089
# 1    2  1.573604e+07      3136.1  0.000199
# 2    3  3.701146e+07      5979.6  0.000162
# 3    4  8.677127e+06       389.2  0.000045
# 4    5  1.671439e+07      6289.5  0.000376
# 5    6  1.321934e+07     12416.1  0.000939
# 6    7  1.545520e+07      2866.9  0.000185
# 7    8  1.642222e+07      4995.4  0.000304
# 8    9  7.347780e+06      6352.5  0.000865
# 9   10  6.972767e+06     87988.8  0.012619
# 10  11  3.078116e+06     93333.1  0.030322
# 11  12  8.613014e+06    131189.1  0.015231

# %%
grouped_region_data.to_csv(r'C:\Users\Kozy-Korpesh\Desktop\dv\Data-Visualization\data\grouped_region_for_map_data.csv',index=False,header=True)

# %%
polydata['density'] = grouped_region_data['density']
# polydata
polydata.drop(['area','perimetro','fumetto','area(m2)','density'], axis=1)
polydata = polydata.set_index('numero_cir')

# %%
# polydata.to_json(r'C:\Users\Kozy-Korpesh\Desktop\dv\Data-Visualization\data\grouped_for_map_data.json')

# %%
with open(r'C:\Users\Kozy-Korpesh\Desktop\dv\Data-Visualization\data\grouped_for_map_data.json', 'w') as f:
    f.write(polydata.to_json())

# %%
stackeddata['count'] = 1
grouped_region_data = stackeddata.groupby(['Region','numero_cir'])['count'].sum() #.sort_values(ascending=False) #.unstack().fillna(0)
grouped_region_data = grouped_region_data.reset_index()
grouped_region_data
# Out:
# <ipython-input-54-fbdaf7ecab08>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stackeddata['count'] = 1
#                           Region  numero_cir  count
# 0                     ARGENTARIO           6    454
# 1                        BONDONE           3    292
# 2   CENTRO STORICO PIEDICASTELLO          12   2964
# 3                        GARDOLO           1   1651
# 4                     MATTARELLO           8    264
# 5                          MEANO           2    206
# 6                   OLTREFERSINA          10   2695
# 7                           POVO           7    189
# 8               RAVINA-ROMAGNANO           5    319
# 9            S.GIUSEPPE-S.CHIARA          11   3024
# 10                      SARDAGNA           4     38
# 11                    VILLAZZANO           9    416

# %%
grouped_region_data = grouped_region_data.rename(columns={"numero_cir": "id"})
grouped_region_data
# Out:
#                           Region  id  count
# 0                     ARGENTARIO   6    454
# 1                        BONDONE   3    292
# 2   CENTRO STORICO PIEDICASTELLO  12   2964
# 3                        GARDOLO   1   1651
# 4                     MATTARELLO   8    264
# 5                          MEANO   2    206
# 6                   OLTREFERSINA  10   2695
# 7                           POVO   7    189
# 8               RAVINA-ROMAGNANO   5    319
# 9            S.GIUSEPPE-S.CHIARA  11   3024
# 10                      SARDAGNA   4     38
# 11                    VILLAZZANO   9    416

# %%
grouped_region_data.to_csv(r'C:\Users\Kozy-Korpesh\Desktop\dv\Data-Visualization\data\grouped_region_for_map_data_tree_abundance.csv',index=False,header=True)
