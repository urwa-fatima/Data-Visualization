# %%
import pandas as pd

# %%
# !pip install geopandas

# %%
import geopandas as gp

# %%
data = gp.read_file("../data/geo_data_trees.geojson")

# %%
data
# Out:
#        Tree ID                    Name DBH (cm) Replacement Value (eur)  \
# 0          1.0     Acer pseudoplatanus        8                  179.43
# 1          2.0     Acer pseudoplatanus        8                  179.43
# 2          3.0     Acer pseudoplatanus        9                  227.09
# 3          4.0     Acer pseudoplatanus       11                  482.46
# 4          7.0               Cupressus       25                 1110.29
# ...        ...                     ...      ...                     ...
# 12508  17664.0            Philadelphus     28.2                  1354.8
# 12509  17665.0  Forsythia x intermedia     28.2                  1354.8
# 12510  17666.0         Aucuba japonica     28.2                  1354.8
# 12511  17667.0      Osmanthus fragrans     28.2                  1354.8
# 12512      NaN                   Total     None                23086243
#
#       Carbon Storage (kg) Carbon Storage (eur)  \
# 0                      12                 1.92
# ...

# %%
data.value_counts("Name").nlargest(10)
# Out:
# Name
# Celtis australis          1028
# Aesculus hippocastanum     581
# Carpinus betulus           536
# Tilia cordata              509
# Platanus x hispanica       502
# Tilia x europaea           471
# Acer campestre             458
# Cupressus                  399
# Sophora japonica           376
# Prunus cerasifera          350
# dtype: int64

# %%
data.groupby('Name').mean()
# Out:
#                            Tree ID   Latitude  Longitude
# Name
# Abies                 12482.625000  46.051824  11.125712
# Abies alba             8826.612903  46.068693  11.119489
# Abies nordmanniana      949.000000  46.006116  11.130692
# Abies pinsapo         13086.000000  46.073739  11.061579
# Acacia                  748.000000  46.011439  11.128209
# ...                            ...        ...        ...
# Viburnum              17540.500000  46.041062  11.137760
# Viburnum sieboldii    15493.500000  46.047793  11.144627
# Wisteria sinensis     15724.250000  46.051914  11.122574
# Zanthoxylum flavum    17539.000000  46.041584  11.136857
# Zelkova carpinifolia  10389.000000  46.090530  11.108478
#
# [225 rows x 3 columns]

# %%
data.dtypes
# Out:
# Tree ID                                 float64
# Name                                     object
# DBH (cm)                                 object
# Replacement Value (eur)                  object
# Carbon Storage (kg)                      object
# Carbon Storage (eur)                     object
# Gross Carbon Sequestration (kg/yr)       object
# Gross Carbon Sequestration (eur/yr)      object
# Avoided Runoff (mcube/yr)                object
# Avoided Runoff (eur/yr)                  object
# Carbon Avoided (kg/yr)                   object
# Carbon Avoided (eur/yr)                  object
# Pollution Removal (g/yr)                 object
# Pollution Removal (eur/yr)               object
# Energy Savings (eur/yr)                  object
# Total Annual Benefits (eur/yr)           object
# Oxygen Production (kg/yr)                object
# Height (m)                               object
# Crown Height (m)                         object
# Crown Width (m)                          object
# ...

# %%
data["Canopy Cover (m2)"]
# Out:
# 0             1.8
# 1             1.8
# 2             1.8
# 3             4.9
# 4             1.8
#            ...
# 12508        21.7
# 12509        21.7
# 12510        21.7
# 12511        21.7
# 12512    382146.7
# Name: Canopy Cover (m2), Length: 12513, dtype: object

# %%
data["Canopy Cover (m2)"].isnull().sum()
# Out:
# 0

# %%
data['canopy_cov'] = data['Canopy Cover (m2)'].astype(float)

# %%
data['canopy_cov']
# Out:
# 0             1.8
# 1             1.8
# 2             1.8
# 3             4.9
# 4             1.8
#            ...
# 12508        21.7
# 12509        21.7
# 12510        21.7
# 12511        21.7
# 12512    382146.7
# Name: canopy_cov, Length: 12513, dtype: float64

# %%
data.to_csv (r'C:\Users\Kozy-Korpesh\Desktop\Data-Visualization\data\export_data.csv', index = False, header=True)
