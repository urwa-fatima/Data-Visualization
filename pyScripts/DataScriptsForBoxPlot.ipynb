# %%
import pandas as pd

# %%
# !pip install geopandas

# %%
import geopandas as gp
import pandas as pd

# %%
data = gp.read_file("../data/geo_data_trees.geojson")

# %%
data.head()
# Out:
#    Tree ID                 Name DBH (cm) Replacement Value (eur)  \
# 0      1.0  Acer pseudoplatanus        8                  179.43
# 1      2.0  Acer pseudoplatanus        8                  179.43
# 2      3.0  Acer pseudoplatanus        9                  227.09
# 3      4.0  Acer pseudoplatanus       11                  482.46
# 4      7.0            Cupressus       25                 1110.29
#
#   Carbon Storage (kg) Carbon Storage (eur) Gross Carbon Sequestration (kg/yr)  \
# 0                  12                 1.92                                1.1
# 1                12.9                 2.07                                1.1
# 2                16.2                 2.61                                1.3
# 3                25.7                 4.13                                1.6
# 4               448.2                72.02                               11.1
#
#   Gross Carbon Sequestration (eur/yr) Avoided Runoff (mcube/yr)  \
# ...

# %%
data
# Out:
#        Tree ID                    Name DBH (cm) Replacement Value (eur)  \
# 0          1.0     Acer pseudoplatanus        8                  179.43
# 1          2.0     Acer pseudoplatanus        8                  179.43
# 2          3.0     Acer pseudoplatanus        9                  227.09
# 3          4.0     Acer pseudoplatanus       11                  482.46
# 4          7.0               Cupressus       25                 1110.29
# ...        ...                     ...      ...                     ...
# 12508  17664.0            Philadelphus     28.2                  1354.8
# 12509  17665.0  Forsythia x intermedia     28.2                  1354.8
# 12510  17666.0         Aucuba japonica     28.2                  1354.8
# 12511  17667.0      Osmanthus fragrans     28.2                  1354.8
# 12512      NaN                   Total     None                23086243
#
#       Carbon Storage (kg) Carbon Storage (eur)  \
# 0                      12                 1.92
# ...

# %%
data.value_counts("Name").nlargest(10)
# Out:
# Name
# Celtis australis          1028
# Aesculus hippocastanum     581
# Carpinus betulus           536
# Tilia cordata              509
# Platanus x hispanica       502
# Tilia x europaea           471
# Acer campestre             458
# Cupressus                  399
# Sophora japonica           376
# Prunus cerasifera          350
# dtype: int64

# %%
data.dtypes
# Out:
# Tree ID                                 float64
# Name                                     object
# DBH (cm)                                 object
# Replacement Value (eur)                  object
# Carbon Storage (kg)                      object
# Carbon Storage (eur)                     object
# Gross Carbon Sequestration (kg/yr)       object
# Gross Carbon Sequestration (eur/yr)      object
# Avoided Runoff (mcube/yr)                object
# Avoided Runoff (eur/yr)                  object
# Carbon Avoided (kg/yr)                   object
# Carbon Avoided (eur/yr)                  object
# Pollution Removal (g/yr)                 object
# Pollution Removal (eur/yr)               object
# Energy Savings (eur/yr)                  object
# Total Annual Benefits (eur/yr)           object
# Oxygen Production (kg/yr)                object
# Height (m)                               object
# Crown Height (m)                         object
# Crown Width (m)                          object
# ...

# %%
data["Height (m)"].isnull().sum()
# Out:
# 1

# %%
data = data[data["Height (m)"].notna()]

# %%
data["Height (m)"]
# Out:
# 0        3.5
# 1          5
# 2        4.5
# 3          5
# 4          8
#         ...
# 12507    2.5
# 12508    2.5
# 12509      8
# 12510      8
# 12511    2.5
# Name: Height (m), Length: 12512, dtype: object

# %%
data['height'] = data['Height (m)'].astype(float)
# Out:
# C:\Users\Kozy-Korpesh\anaconda3\lib\site-packages\geopandas\geodataframe.py:1443: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
data['height']
# Out:
# 0        3.5
# 1        5.0
# 2        4.5
# 3        5.0
# 4        8.0
#         ...
# 12507    2.5
# 12508    2.5
# 12509    8.0
# 12510    8.0
# 12511    2.5
# Name: height, Length: 12512, dtype: float64

# %%
data_converted = data[['height','Name']].groupby('Name')['height'].apply(list).reset_index(name='height_list')

# %%
data.value_counts("Name")
# Out:
# Name
# Celtis australis          1028
# Aesculus hippocastanum     581
# Carpinus betulus           536
# Tilia cordata              509
# Platanus x hispanica       502
#                           ...
# Syringa vulgaris             1
# Lagerstroemia                1
# Catalpa                      1
# Prunus amygdalus             1
# Cornus nuttallii             1
# Length: 224, dtype: int64

# %%
# data_converted['count'] = data.value_counts("Name")

# %%
data_converted
# Out:
#                      Name                                        height_list
# 0                   Abies          [7.0, 5.0, 12.0, 9.0, 7.0, 9.0, 9.0, 7.0]
# 1              Abies alba  [12.2, 12.2, 12.2, 12.2, 14.0, 10.0, 10.0, 15....
# 2      Abies nordmanniana                                              [8.0]
# 3           Abies pinsapo                                             [14.0]
# 4                  Acacia                                             [14.0]
# ..                    ...                                                ...
# 219              Viburnum                                         [8.0, 8.0]
# 220    Viburnum sieboldii                                         [8.0, 8.0]
# 221     Wisteria sinensis                               [0.8, 0.8, 0.8, 3.0]
# 222    Zanthoxylum flavum                                              [8.0]
# 223  Zelkova carpinifolia                          [4.0, 4.0, 4.0, 3.5, 4.0]
#
# [224 rows x 2 columns]

# %%
data_converted['len'] = data_converted['height_list'].str.len()

# %%
data_converted
# Out:
#                      Name                                        height_list  \
# 0                   Abies          [7.0, 5.0, 12.0, 9.0, 7.0, 9.0, 9.0, 7.0]
# 1              Abies alba  [12.2, 12.2, 12.2, 12.2, 14.0, 10.0, 10.0, 15....
# 2      Abies nordmanniana                                              [8.0]
# 3           Abies pinsapo                                             [14.0]
# 4                  Acacia                                             [14.0]
# ..                    ...                                                ...
# 219              Viburnum                                         [8.0, 8.0]
# 220    Viburnum sieboldii                                         [8.0, 8.0]
# 221     Wisteria sinensis                               [0.8, 0.8, 0.8, 3.0]
# 222    Zanthoxylum flavum                                              [8.0]
# 223  Zelkova carpinifolia                          [4.0, 4.0, 4.0, 3.5, 4.0]
#
#      len
# 0      8
# 1     31
# 2      1
# ...

# %%
data_converted = data_converted.sort_values(by=['len'], ascending=False)

# %%
data_converted
# Out:
#                        Name  \
# 44         Celtis australis
# 20   Aesculus hippocastanum
# 37         Carpinus betulus
# 207           Tilia cordata
# 150    Platanus x hispanica
# ..                      ...
# 198        Syringa vulgaris
# 96            Lagerstroemia
# 38                  Catalpa
# 156        Prunus amygdalus
# 51         Cornus nuttallii
#
#                                            height_list   len
# 44   [6.0, 6.0, 6.0, 5.5, 6.5, 4.5, 5.0, 4.5, 4.5, ...  1028
# 20   [15.0, 15.0, 14.0, 16.0, 6.0, 6.0, 14.0, 12.0,...   581
# 37   [4.5, 4.0, 5.0, 4.5, 4.0, 4.0, 4.5, 12.0, 12.0...   536
# 207  [4.5, 5.0, 5.0, 4.0, 6.0, 7.0, 7.0, 7.0, 4.5, ...   509
# 150  [15.0, 11.0, 7.0, 6.0, 7.0, 8.0, 6.0, 6.0, 5.0...   502
# ..                                                 ...   ...
# 198                                              [8.0]     1
# 96                                              [20.0]     1
# 38                                              [11.0]     1
# ...

# %%
data_converted = data_converted.iloc[:10]

# %%
data_converted
# Out:
#                        Name  \
# 44         Celtis australis
# 20   Aesculus hippocastanum
# 37         Carpinus betulus
# 207           Tilia cordata
# 150    Platanus x hispanica
# 211        Tilia x europaea
# 7            Acer campestre
# 59                Cupressus
# 191        Sophora japonica
# 158       Prunus cerasifera
#
#                                            height_list   len
# 44   [6.0, 6.0, 6.0, 5.5, 6.5, 4.5, 5.0, 4.5, 4.5, ...  1028
# 20   [15.0, 15.0, 14.0, 16.0, 6.0, 6.0, 14.0, 12.0,...   581
# 37   [4.5, 4.0, 5.0, 4.5, 4.0, 4.0, 4.5, 12.0, 12.0...   536
# 207  [4.5, 5.0, 5.0, 4.0, 6.0, 7.0, 7.0, 7.0, 4.5, ...   509
# 150  [15.0, 11.0, 7.0, 6.0, 7.0, 8.0, 6.0, 6.0, 5.0...   502
# 211  [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 6.0, 5.0, 8.0, ...   471
# 7    [6.0, 8.0, 4.0, 5.0, 11.0, 8.0, 5.0, 5.0, 5.0,...   458
# 59   [8.0, 10.0, 10.0, 10.0, 14.0, 14.0, 14.0, 14.0...   399
# 191  [5.0, 5.0, 5.0, 6.0, 5.0, 4.0, 5.0, 5.0, 5.0, ...   376
# ...

# %%
data_converted.to_csv (r'C:\Users\Kozy-Korpesh\Desktop\dv\Data-Visualization\data\export_data_box_plot.csv', index = False, header=True)
